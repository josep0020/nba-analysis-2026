# %% [markdown]
# # Análisis Exploratorio de Jugadores NBA 2026
# El objetivo de este cuaderno es analizar las estadísticas de los jugadores durante la temporada para identificar a los líderes en anotación, eficiencia y trabajo en equipo.

# %%
import pandas as pd

# %%
nba = pd.read_csv('nba_player_stats_2026.csv')
nba.columns
nba.head(4)
# Out:
#    PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0    1629029     1              Luka Dončić  1610612747  LAL  64  2289  693
# 1    1628983     2  Shai Gilgeous-Alexander  1610612760  OKC  68  2259  731
# 2    1627759     3             Jaylen Brown  1610612738  BOS  71  2443  736
# 3     201142     4             Kevin Durant  1610612745  HOU  78  2840  716
#
#     FGA  FG_PCT  ...  REB  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  \
# 0  1457   0.476  ...  495  530  105   34  255  153  2143  2146     2.08
# 1  1321   0.553  ...  292  448   95   52  151  139  2117  2189     2.97
# 2  1543   0.477  ...  492  364   72   27  259  191  2038  1817     1.41
# 3  1376   0.520  ...  426  372   62   71  246  142  2026  1992     1.51
#
#    STL_TOV
# 0     0.41
# 1     0.63
# 2     0.28
# 3     0.25
#
# [4 rows x 28 columns]

# %%
# Ordenar los equipos por porcentaje de acierto en triples para ver los líderes
lideres_triples = eficiencia_triples.sort_values(by='TEAM_FG3_PCT', ascending=False)
lideres_triples.head()
