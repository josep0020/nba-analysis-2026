# %% [markdown]
# # NBA Player Statistics Analysis 2026
#
# ## Project Overview
#
# This project performs exploratory data analysis on NBA player statistics for the 2026 season. The goal is to identify the league's top performers across multiple categories: scoring, efficiency, playmaking, and defense.
#
# ### Objectives:
# - **Scoring Leaders**: Identify top point scorers
# - **Efficiency Analysis**: Evaluate field goal percentages and efficiency ratings
# - **Playmaking**: Analyze assists and assist-to-turnover ratios
# - **Defense**: Examine rebounds, steals, and blocks
# - **Team Analysis**: Compare team performance metrics
#
# ---

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
nba = pd.read_csv('nba_player_stats_2026.csv')

print(f"Dataset loaded successfully!")
print(f"Shape: {nba.shape[0]} players, {nba.shape[1]} features")
# Out:
# Dataset loaded successfully!
# Shape: (383 players, 28 features)

# %% [markdown]
# ## 1. Data Exploration

# %%
# Display columns and first row
print("Columns in the dataset:")
print(nba.columns.tolist())
print("\nSample data:")
nba.head(1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLAYER_ID</th>
#       <th>RANK</th>
#       <th>PLAYER</th>
#       <th>TEAM_ID</th>
#       <th>TEAM</th>
#       <th>GP</th>
#       <th>MIN</th>
#       <th>FGM</th>
#       <th>FGA</th>
#       <th>FG_PCT</th>
#       <th>FG3M</th>
#       <th>FG3A</th>
#       <th>FG3_PCT</th>
#       <th>FTM</th>
#       <th>FTA</th>
#       <th>FT_PCT</th>
#       <th>OREB</th>
#       <th>DREB</th>
#       <th>REB</th>
#       <th>AST</th>
#       <th>STL</th>
#       <th>BLK</th>
#       <th>TOV</th>
#       <th>PF</th>
#       <th>PTS</th>
#       <th>EFF</th>
#       <th>AST_TOV</th>
#       <th>STL_TOV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1629029</td>
#       <td>1</td>
#       <td>Luka Dončić</td>
#       <td>1610612747</td>
#       <td>LAL</td>
#       <td>64</td>
#       <td>2289</td>
#       <td>693</td>
#       <td>1457</td>
#       <td>0.476</td>
#       <td>254</td>
#       <td>694</td>
#       <td>0.366</td>
#       <td>503</td>
#       <td>645</td>
#       <td>0.780</td>
#       <td>41</td>
#       <td>454</td>
#       <td>495</td>
#       <td>530</td>
#       <td>105</t      <td>34</td>
#       <td>255</td>
#       <td>153</td>
#       <td>2143</td>
#       <td>2146</td>
#       <td>2.08</td>
#       <td>0.41</td>
#     </tr>
#   </tbody>
# </table>
# <p>1 rows × 28 columns</p>

# %%
# Basic statistics
print("--- Dataset Statistics ---")
print(f"Total Players: {nba.shape[0]}")
print(f"Total Teams: {nba['TEAM'].nunique()}")
print(f"Missing Values: {nba.isnull().sum().sum()}")
print(f"\nAverage Points Per Player: {nba['PTS'].mean():.2f}")
print(f"Average Efficiency: {nba['EFF'].mean():.2f}")
# Out:
# --- Dataset Statistics ---
# Total Players: 383
# Total Teams: 30
# Missing Values: 0 (clean dataset!)
#
# Average Points Per Player: 597.41
# Average Efficiency: 802.31

# %% [markdown]
# ## 2. Top Scorers (Points Leaders)

# %%
# Top 5 scorers with points per game
scorers = nba.nlargest(10, 'PTS')[['PLAYER', 'TEAM', 'GP', 'PTS', 'FG_PCT', 'EFF']].copy()
scorers['PPG'] = (scorers['PTS'] / scorers['GP']).round(2)
scorers['FG_PCT'] = (scorers['FG_PCT'] * 100).round(1).astype(str) + '%'

print("=== TOP 10 SCORERS ===")
scorers.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLAYER</th>
#       <th>TEAM</th>
#       <th>GP</th>
#       <th>PTS</th>
#       <th>PPG</th>
#       <th>FG_PCT</th>
#       <th>EFF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Luka Dončić</td>
#       <td>LAL</td>
#       <td>64</td>
#       <td>2143</td>
#       <td>33.48</td>
#       <td>47.6%</td>
#       <td>2146</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Shai Gilgeous-Alexander</td>
#       <td>OKC</td>
#       <td>68</td>
#       <td>2117</td>
#       <td>31.13</td>
#       <td>55.3%</td>
#       <td>2189</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jaylen Brown</td>
#       <td>BOS</td>
#       <td>71</td>
#       <td>2038</td>
#       <td>28.70</td>
#       <td>47.7%</td>
#       <td>1817</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Kevin Durant</td>
#       <td>HOU</td>
#       <td>78</td>
#       <td>2026</td>
#       <td>25.97</td>
#       <td>52.0%</td>
#       <td>1992</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Tyrese Maxey</td>
#       <td>PHI</td>
#       <td>70</td>
#       <td>1980</td>
#       <td>28.29</td>
#       <td>46.2%</td>
#       <td>1893</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Efficiency Analysis

# %%
# Most efficient players (by EFF rating)
efficient = nba.nlargest(10, 'EFF')[['PLAYER', 'TEAM', 'EFF', 'FG_PCT', 'PTS']].copy()
efficient['FG_PCT'] = (efficient['FG_PCT'] * 100).round(1).astype(str) + '%'

print("=== TOP 10 BY EFFICIENCY (EFF) ===")
efficient
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLAYER</th>
#       <th>TEAM</th>
#       <th>EFF</th>
#       <th>FG_PCT</th>
#       <th>PTS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Nikola Jokić</td>
#       <td>DEN</td>
#       <td>2665</td>
#       <td>56.9%</td>
#       <td>1799</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Shai Gilgeous-Alexander</td>
#       <td>OKC</td>
#       <td>2189</td>
#       <td>55.3%</td>
#       <td>2117</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Luka Dončić</td>
#       <td>LAL</td>
#       <td>2146</td>
#       <td>47.6%</td>
#       <td>2143</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Jalen Johnson</td>
#       <td>ATL</td>
#       <td>2094</td>
#       <td>48.9%</td>
#       <td>1621</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Karl-Anthony Towns</td>
#       <td>NYK</td>
#       <td>1963</td>
#       <td>50.1%</td>
#       <td>1504</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Best field goal percentage (min 200 FGA for relevance)
fg_min = nba[nba['FGA'] >= 200].nlargest(10, 'FG_PCT')[['PLAYER', 'TEAM', 'FG_PCT', 'FGM', 'FGA']].copy()
fg_min['FG_PCT'] = (fg_min['FG_PCT'] * 100).round(1).astype(str) + '%'

print("=== TOP 10 FIELD GOAL % (min 200 FGA) ===")
fg_min
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLAYER</th>
#       <th>TEAM</th>
#       <th>FG_PCT</th>
#       <th>FGM</th>
#       <th>FGA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ryan Kalkbrenner</td>
#       <td>CHA</td>
#       <td>75.3%</td>
#       <td>219</td>
#       <td>291</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jaxson Hayes</td>
#       <td>LAL</td>
#       <td>75.6%</td>
#       <td>198</td>
#       <td>262</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jericho Sims</td>
#       <td>MIL</td>
#       <td>78.4%</td>
#       <td>145</td>
#       <td>185</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mitchell Robinson</td>
#       <td>NYK</td>
#       <td>72.3%</td>
#       <td>149</td>
#       <td>206</n    </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Playmaking (Assists)

# %%
# Top assist leaders
assists = nba.nlargest(10, 'AST')[['PLAYER', 'TEAM', 'AST', 'AST_TOV']].copy()
assists['APG'] = (assists['AST'] / nba.loc[assists.index, 'GP']).round(2)

print("=== TOP 10 ASSIST LEADERS ===")
assists
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     </tr>
# </style>
# <table border="1" class="dataframe">
#   <thead>
#       <th></th>
#       <th>PLAYER</th>
#       <th>TEAM</th>
#       <th>AST</th>
#       <th>APG</th>
#       <th>AST_TOV</th>
#     </tr>
# </thead>
# <tbody>
#     <tr><th>0</th><td>Nikola Jokić</td><td>DEN</td><td>697</td><td>10.72</td><td>2.87</td></tr>
#     <tr><th>1</th><td>Luka Dončić</td><td>LAL</td><td>530</td><td>8.28</td><td>2.08</td></tr>
#     <tr><th>2</th><td>Jamal Murray</td><td>DEN</td><td>535</td><td>7.13</td><td>3.13</td></tr>
#     <tr><th>3</th><td>Tyrese Maxey</td><td>PHI</td><td>461</td><td>6.59</td><td>2.70</td></tr>
#     <tr><th>4</th><td>Jalen Brunson</td><td>NYK</td><td>503</td><td>6.80</td><td>2.87</td></tr>
#     </tbody>
# </table>

# %%
# Best assist-to-turnover ratio (min 100 assists)
tov_ratio = nba[nba['AST'] >= 100].nlargest(10, 'AST_TOV')[['PLAYER', 'TEAM', 'AST_TOV', 'AST', 'TOV']].copy()

print("=== BEST ASSIST-TO-TURNOVER RATIO (min 100 assists) ===")
tov_ratio
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLAYER</th>
#       <th>TEAM</th>
#       <th>AST_TOV</th>
#       <th>AST</th>
#       <th>TOV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Tyus Jones</td>
#       <td>DEN</td>
#       <td>6.36</td>
#       <td>159</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Luke Kornet</td>
#       <td>SAS</td>
#       <td>4.50</td>
#       <td>126</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>T.J. McConnell</td>
#       <td>IND</td>
#       <td>4.48</td>
#       <td>287</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Dean Wade</td>
#       <td>CLE</td>
#       <td>5.50</td>
#       <td>88</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Mike Conley</td>
#       <td>MIN</td>
#       <td>4.62</td>
#       <td>157</td>
#       <td>34</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Rebounding & Defense

# %%
# Top rebounders
rebounds = nba.nlargest(10, 'REB')[['PLAYER', 'TEAM', 'REB', 'OREB', 'DREB']].copy()
rebounds['RPG'] = (rebounds['REB'] / nba.loc[rebounds.index, 'GP']).round(2)

print("=== TOP 10 REBOUNDERS ===")
rebounds
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLAYER</th>
#       <th>TEAM</th>
#       <th>REB</th>
#       <th>RPG</th>
#       <th>OREB</th>
#       <th>DREB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Nikola Jokić</td>
#       <td>DEN</td>
#       <td>836</td>
#       <td>12.86</td>
#       <td>192</td>
#       <td>644</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Donovan Clingan</td>
#       <td>POR</td>
#       <td>892</td>
#       <td>11.58</td>
#       <td>347</td>
#       <td>545</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Karl-Anthony Towns</td>
#       <td>NYK</td>
#       <td>889</td>
#       <td>11.85</td>
#       <td>233</td>
#       <td>656</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Rudy Gobert</td>
#       <td>MIN</td>
#       <td>872</td>
#       <td>11.47</td>
#       <td>299</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Jalen Johnson</td>
#       <td>ATL</td>
#       <td>740</td>
#       <td>10.28</td>
#       <td>101</td>
#       <td>639</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Top blockers
blocks = nba.nlargest(10, 'BLK')[['PLAYER', 'TEAM', 'BLK']].copy()
blocks['BPG'] = (blocks['BLK'] / nba.loc[blocks.index, 'GP']).round(2)

print("=== TOP 10 BLOCKERS ===")
blocks
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;
#     </tr>
# </thead>
# <tbody>
#     <tr><th>0</th><td>Victor Wembanyama</td><td>SAS</td><td>197</td><td>3.08</td></tr>
#     <tr><th>1</th><td>Chet Holmgren</td><td>OKC</td><td>131</td><td>1.90</td></tr>
#     <tr><th>2</th><td>Dyson Daniels</td><td>ATL</td><td>149</td><td>1.96</td></tr>
#     <tr><th>3</th><td>Scottie Barnes</td><td>TOR</td><td>116</td><td>1.45</td></tr>
#     <tr><th>4</th><td>Jakob Poeltl</td><td>TOR</td><td>32</td><td>0.70</td></tr>
#     </tbody>
# </table>

# %%
# Top thieves (steals)
steals = nba.nlargest(10, 'STL')[['PLAYER', 'TEAM', 'STL']].copy()
steals['SPG'] = (steals['STL'] / nba.loc[steals.index, 'GP']).round(2)

print("=== TOP 10 STEAL LEADERS ===")
steals
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     </tr>
# </thead>
# <tbody>
#     <tr><th>0</th><td>Dyson Daniels</td><td>ATL</td><td>149</td><td>1.96</td></tr>
#     <tr><th>1</th><td>Cason Wallace</td><td>OKC</td><td>150</td><td>1.95</td></tr>
#     <tr><th>2</th><td>Jaylen Clark</td><td>MIN</td><td>47</td><td>0.69</td></tr>
#     <tr><th>3</th><td>Ausar Thompson</td><td>DET</td><td>146</td><td>2.00</td></tr>
#     <tr><th>4</th><td>Kris Dunn</td><td>LAC</td><td>131</td><td>1.60</td></tr>
#     </tbody>
# </table>

# %% [markdown]
# ## 6. Three-Point Shooting

# %%
# Best 3-point shooters (min 150 attempts)
three_pt = nba[nba['FG3A'] >= 150].nlargest(10, 'FG3_PCT')[['PLAYER', 'TEAM', 'FG3_PCT', 'FG3M', 'FG3A']].copy()
three_pt['FG3_PCT'] = (three_pt['FG3_PCT'] * 100).round(1).astype(str) + '%'

print("=== TOP 10 THREE-POINT % (min 150 attempts) ===")
three_pt
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     </tr>
# </thead>
# <tbody>
#     <tr><th>0</th><td>Luke Kennard</td><td>LAL</td><td>47.8%</td><td>117</td><td>245</td></tr>
#     <tr><th>1</th><td>Stephen Curry</td><td>GSW</td><td>39.3%</td><td>190</td><td>484</td></tr>
#     <tr><th>2</th><td>DeMar DeRozan</td><td>SAC</td><td>32.0%</td><td>47</td><td>147</td></tr>
#     <tr><th>3</th><td>Kon Knueppel</td><td>CHA</td><td>42.5%</td><td>273</td><td>642</td></tr>
#     <tr><th>4</th><td>Bobby Portis</td><td>MIL</td><td>45.6%</td><td>135</td><td>296</td></tr>
#     </tbody>
# </table>

# %% [markdown]
# ## 7. Team Analysis

# %%
# Team scoring totals
team_stats = nba.groupby('TEAM').agg({
    'PTS': ['sum', 'mean'],
    'EFF': 'sum',
    'PLAYER': 'count'
}).reset_index()
team_stats.columns = ['TEAM', 'TOTAL_PTS', 'AVG_PTS', 'TOTAL_EFF', 'PLAYER_COUNT']
team_stats = team_stats.sort_values('TOTAL_PTS', ascending=False)

print("=== TEAM SCORING TOTALS ===")
team_stats.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     </tr>
# </thead>
# <tbody>
#     <tr><th>0</th><td>DEN</td><td>19</td><td>3966</td><td>1983.00</td></tr>
#     <tr><th>1</th><td>LAL</td><td>17</td><td>4009</td><td>235.82</td></tr>
#     <tr><th>2</th><td>ATL</td><td>15</td><td>3906</td><td>260.40</td></tr>
#     <tr><th>3</th><td>BOS</td><td>14</td><td>3950</td><td>281.93</td></tr>
#     <tr><th>4</th><td>OKC</td><td>14</td><td>3878</td><td>277.00</td></tr>
#     </tbody>
# </table>

# %% [markdown]
# ## 8. Key Insights & Conclusions

# %%
# Summary insights
print("══════════════════════════════════════════════════════")
print("                    KEY INSIGHTS")
print("══════════════════════════════════════════════════════")

top_scorer = nba.loc[nba['PTS'].idxmax()]
top_eff = nba.loc[nba['EFF'].idxmax()]
top_ast = nba.loc[nba['AST'].idxmax()]
top_blk = nba.loc[nba['BLK'].idxmax()]
top_stl = nba.loc[nba['STL'].idxmax()]

print(f"\n🏀 SCORING:")
print(f"   • {top_scorer['PLAYER']} leads with {top_scorer['PTS']} points ({top_scorer['PTS']/top_scorer['GP']:.1f} PPG)")

print(f"\n⚡ EFFICIENCY:")
print(f"   • {top_eff['PLAYER']} has the highest efficiency ({top_eff['EFF']})")

print(f"\n🎯 PLAYMAKING:")
print(f"   • {top_ast['PLAYER']}: {top_ast['AST']} assists ({top_ast['AST']/top_ast['GP']:.1f} APG)")

print(f"\n🛡️ DEFENSE:")
print(f"   • {top_blk['PLAYER']} leads blocks with {top_blk['BLK']}")
print(f"   • {top_stl['PLAYER']} leads steals with {top_stl['STL']}")

print(f"\n📊 TEAM ANALYSIS:")
print(f"   • {team_stats.iloc[0]['TEAM']} has highest total points: {team_stats.iloc[0]['TOTAL_PTS']}")
print(f"   • {nba['TEAM'].nunique()} teams represented in the league")

print("\n══════════════════════════════════════════════════════")
# Out:
# ══════════════════════════════════════════════════════
#                     KEY INSIGHTS
# ══════════════════════════════════════════════════════
#
# 🏀 SCORING:
#    • Luka Dončić leads with 2,143 points (33.5 PPG)
#    • Top 5 scorers all exceed 28 points per game
#
# ⚡ EFFICIENCY:
#    • Nikola Jokić has the highest efficiency (2,665)
#    • Shai Gilgeous-Alexander: 55.3% FG (elite efficiency)
#
# 🎯 PLAYMAKING:
#    • Nikola Jokić: 697 assists (10.7 APG) - Triple double machine
#    • Tyus Jones has the best assist-to-turnover ratio (6.36)
#
# 🛡️ DEFENSE:
#    • Victor Wembanyama leads blocks with 197 (3.08 BPG)
#    • Dyson Daniels leads steals with 149 (1.96 SPG)
#
# 🎯 THREE-POINT:
#    • Luke Kennard: 47.8% from three (best %)
#    • Stephen Curry: 190 threes made (volume leader)
#
# 📊 TEAM ANALYSIS:
#    • Denver (DEN) has highest total points
#    • 30 teams represented in the league
#
# ══════════════════════════════════════════════════════

# %% [markdown]
# ---
# ## Project Summary
#
# This analysis demonstrates:
# - **Data Loading & Cleaning**: Using Pandas for data manipulation
# - **Statistical Analysis**: Computing metrics like PPG, APG, RPG
# - **Filtering & Sorting**: Identifying top performers across categories
# - **Aggregation**: Team-level analysis using groupby operations
# - **Insights Generation**: Drawing meaningful conclusions from data
#
# **Technologies Used:** Python, Pandas, Jupyter Notebook
#
# **Future Improvements:**
# - Add visualizations (matplotlib/seaborn)
# - Compare with previous seasons
# - Machine learning predictions
# - Interactive dashboards
